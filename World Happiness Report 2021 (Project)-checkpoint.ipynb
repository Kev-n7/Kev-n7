# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['figure.facecolor'] = '#FFE5B4'

# %%
df = pd.read_csv('C:/Users/kev/Downloads/world-happiness-report-2021.csv')

# %%
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
#Picking Important names of interest from the column for analysis
df_columns = ['Country name', 'Regional indicator', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']

# %%
df = df[df_columns].copy()

# %%
#Renaming the names in the column
happy_df = df.rename({'Country name':'country_name', 'Regional indicator':'regional_indicator', 'Logged GDP per capita':'logged_GDP_per_capita', 'Social support':'social_support', 'Healthy life expectancy':'healthy_life_expectancy', 'Freedom to make life choices':'freedom_to_make_life_choice', 'Generosity':'generosity', 'Perceptions of corruption':'perceptions_of_corruption'}, axis =1)

# %%
happy_df.head()
# Out:
#   country_name regional_indicator  logged_GDP_per_capita  social_support  \
# 0      Finland     Western Europe                 10.775           0.954
# 1      Denmark     Western Europe                 10.933           0.954
# 2  Switzerland     Western Europe                 11.117           0.942
# 3      Iceland     Western Europe                 10.878           0.983
# 4  Netherlands     Western Europe                 10.932           0.942
#
#    healthy_life_expectancy  freedom_to_make_life_choice  generosity  \
# 0                     72.0                        0.949      -0.098
# 1                     72.7                        0.946       0.030
# 2                     74.4                        0.919       0.025
# 3                     73.0                        0.955       0.160
# 4                     72.4                        0.913       0.175
#
#    perceptions_of_corruption
# 0                      0.186
# 1                      0.179
# ...

# %%
# Checking if the columns has null values in the dataset
happy_df.isnull().sum()
# Out:
# country_name                   0
# regional_indicator             0
# logged_GDP_per_capita          0
# social_support                 0
# healthy_life_expectancy        0
# freedom_to_make_life_choice    0
# generosity                     0
# perceptions_of_corruption      0
# dtype: int64

# %%
# plot between GDP and social support

plt.rcParams['figure.figsize'] = (15, 7)
plt.title('Plot between GDP and Social support')
sns.scatterplot(x = happy_df.logged_GDP_per_capita, y =  happy_df.social_support, hue = happy_df.regional_indicator, s = 200);
plt.legend(loc = 'upper left', fontsize = '10')
plt.xlabel('GDP per capita')
plt.ylabel('Social support')
# Out:
# Text(0, 0.5, 'Social support')

# %%
# Checking for the logged_GDP_Per_Capital by Summing up the regional_indicator 
gdp_region = happy_df.groupby('regional_indicator')['logged_GDP_per_capita'].sum()
gdp_region
# Out:
# regional_indicator
# Central and Eastern Europe            171.854
# Commonwealth of Independent States    112.822
# East Asia                              62.206
# Latin America and Caribbean           187.400
# Middle East and North Africa          164.324
# North America and ANZ                  43.238
# South Asia                             60.778
# Southeast Asia                         84.793
# Sub-Saharan Africa                    290.707
# Western Europe                        227.277
# Name: logged_GDP_per_capita, dtype: float64

# %%
# Countries with the lowest perception of corruption
country = happy_df.sort_values(by='perceptions_of_corruption').head(10)
plt.rcParams['figure.figsize'] = (12,6)
plt.title('Countries With Most Perception of Corruption')
plt.xlabel('Country', fontsize = 13) 
plt.ylabel('Corruption Index', fontsize =13)
plt.xticks(rotation = 30, ha='right')
plt.bar(country.country_name, country.perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
#  Countries with the most perception of corruption
country = happy_df.sort_values(by='perceptions_of_corruption').tail(10)
plt.rcParams['figure.figsize'] = (12,6)
plt.title('Countries With Most Perception of Corruption')
plt.xlabel('Country', fontsize = 13) 
plt.xlabel('Corruption Index', fontsize =13)
plt.xticks(rotation = 30, ha='right')
plt.bar(country.country_name, country.perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
# Perception of corruption Vs freedom to make life choices

plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot between freedom to make choices and perceptions of corruption')
sns.scatterplot(x = happy_df.freedom_to_make_life_choice, y=happy_df.perceptions_of_corruption, hue=happy_df.regional_indicator, s=100)
plt.legend(loc='lower left', fontsize = '14')
plt.xlabel('Freedom of Choice')
plt.ylabel('Corruption')
# Out:
# Text(0, 0.5, 'Corruption')

# %%
# Plot in a Pie Chart
gdp_region.plot.pie(autopct = '%1.1f%%')
plt.title('GDP by Region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Total countries

total_country = happy_df.groupby('regional_indicator')[['country_name']].count()
print(total_country)
# Out:
#                                     country_name
# regional_indicator
# Central and Eastern Europe                    17
# Commonwealth of Independent States            12
# East Asia                                      6
# Latin America and Caribbean                   20
# Middle East and North Africa                  17
# North America and ANZ                          4
# South Asia                                     7
# Southeast Asia                                 9
# Sub-Saharan Africa                            36
# Western Europe                                21

# %%
# Correlation Map

cor = happy_df.corr(method = "pearson")
f, ax = plt.subplots(figsize = (10, 5))
sns.heatmap(cor, mask = np.zeros_like(cor, dtype='bool'),
            cmap="Blues", square=True, ax=ax)
# Out:
# C:\Users\kev\AppData\Local\Temp\ipykernel_9572\1132194608.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = happy_df.corr(method = "pearson")
# <Axes: >

# %%
# corruption in regions

corruption = happy_df.groupby('regional_indicator')[['perceptions_of_corruption']].mean()
corruption
# Out:
#                                     perceptions_of_corruption
# regional_indicator
# Central and Eastern Europe                           0.850529
# Commonwealth of Independent States                   0.725083
# East Asia                                            0.683333
# Latin America and Caribbean                          0.792600
# Middle East and North Africa                         0.762235
# North America and ANZ                                0.449250
# South Asia                                           0.797429
# Southeast Asia                                       0.709111
# Sub-Saharan Africa                                   0.765944
# Western Europe                                       0.523095

# %%
# Perception of corruption in various Regions 
plt.rcParams['figure.figsize'] = (12, 8)
plt.title('perception of Corruption in various Regions', size = 25)
plt.xlabel('Regions', fontsize = 15)
plt.ylabel('Corruption Index', fontsize = 15)
plt.xticks(rotation = 30, ha='right')
plt.bar(corruption.index, corruption.perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
top_10 = happy_df.head(10)
bottom_10 = happy_df.tail(10)

# %%
fig, axes= plt.subplots(1,2, figsize= (16, 6))
plt.tight_layout(pad= 2)
xlabel= top_10.country_name
axes[0].set_title('Top 10 happiest countries Life Expectancy')
axes[0].set_xticklabels(xlabel, rotation=45, ha='right')
sns.barplot(x= top_10.country_name, y= top_10.healthy_life_expectancy, ax= axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Life Expectancy')

xlabels= bottom_10.country_name
axes[1].set_title('Bottom 10 least happy countries Life Expectancy')
axes[1].set_xticklabels(xlabel, rotation=45, ha='right')
sns.barplot(x= bottom_10.country_name, y= bottom_10.healthy_life_expectancy, ax= axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Life Expectancy')
# Out:
# C:\Users\kev\AppData\Local\Temp\ipykernel_9572\1568922025.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(xlabel, rotation=45, ha='right')
# C:\Users\kev\AppData\Local\Temp\ipykernel_9572\1568922025.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(xlabel, rotation=45, ha='right')
# Text(832.0858585858584, 0.5, 'Life Expectancy')

# %%
# Freedom to make life choices vs Life Expectancy

plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot between Freedom to make life choices and Life Expectancy ')
sns.scatterplot(x = happy_df.freedom_to_make_life_choice, y=happy_df.healthy_life_expectancy, hue=happy_df.regional_indicator, s=100)
plt.legend(loc='lower left', fontsize = '14')
plt.xlabel('Freedom of Choice')
plt.ylabel('Life Expectancy')
# Out:
# Text(0, 0.5, 'Life Expectancy')

# %%
#  Countries with the least perception of corruption
country = happy_df.sort_values(by='perceptions_of_corruption').head(10)
plt.rcParams['figure.figsize'] = (12,6)
plt.title('Countries With Most Perception of Corruption')
plt.xlabel('Country', fontsize = 13) 
plt.xlabel('Corruption Index', fontsize =13)
plt.xticks(rotation = 30, ha='right')
plt.bar(country.country_name, country.perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
#  Countries with the most perception of corruption
country = happy_df.sort_values(by='perceptions_of_corruption').tail(10)
plt.rcParams['figure.figsize'] = (12,6)
plt.title('Countries With Most Perception of Corruption')
plt.xlabel('Country', fontsize = 13) 
plt.xlabel('Corruption Index', fontsize =13)
plt.xticks(rotation = 30, ha='right')
plt.bar(country.country_name, country.perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
# Social Support vs Generosity

plt.rcParams['figure.figsize']=(15,7)
plt.title('Plot between Social Support and Generosity')
sns.scatterplot(x = happy_df.social_support, y=happy_df.generosity, hue=happy_df.regional_indicator, s=100)
plt.legend(loc='lower left', fontsize = '14')
plt.xlabel('Social Support')
plt.ylabel('Generosity')
# Out:
# Text(0, 0.5, 'Generosity')
